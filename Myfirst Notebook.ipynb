# %% [markdown]
# My first Notebook

# %%
# Let's check What Version of Python we're running
import sys
print('Hello Python!')
print(f"Python Version : {sys.version}")

# %%
# %sql
Select * from samples.nyctaxi.trips;

# %% [markdown]
# # Header 1
# Header1
# ## Header 2
# Header 2 **Bold** Therse is also *italics*
# ### Header3
# 'Select * from Table'
#
# - first item
#   - sub item
#     1. sub sub item
#     2. sub sub item
# [My git hub url](https://github.com/CognativeEnterprise/DataBricksAcademy.git)
